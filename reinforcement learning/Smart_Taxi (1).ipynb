# %%
import numpy as np
import random
import gym
import time

#exploration and exploitation policy ->to determine action
def  policy(q,state):
     #exploitation
     if(random.uniform(0,1)>epsilon):
      action=np.argmax(q[state])
    #exploration
     else:
        action=env.action_space.sample()
     return action

env=gym.make("Taxi-v3",render_mode='ansi').env
env.reset()
env.render()[0]

#state and action creation

state_space=env.observation_space.n
print("possible states:",state_space)
action_space=env.action_space.n
print("possible action:",action_space)


#creating q-table
q=np.zeros((state_space,action_space))

#hyper parameters

total_noof_episodes=25000
total_test_episodes=10
max_steps=200

learning_rate=0.01
gamma=0.99  #discount rate

#exploration parameters
epsilon=1.0  #exploration rate
max_epsilon=1.0 # max exploration at the start
min_epsilon=0.001 # min probability in the begnining
decay=0.01


#training
for ep in range(total_noof_episodes):
  state=env.reset()
  step=0
  done=False

  epsilon=min_epsilon+(max_epsilon-min_epsilon)*np.exp(-decay*ep)

  for step in range(max_steps):
   action=policy(q,state)
   new_state,reward,done,info=env.step(action)

   #update value
   q[state][action]=q[state][action]+ learning_rate*(reward+gamma*np.max(q[new_state])-q[state][action]) #q learning formula

   if done==True:
    break

   state=new_state

#running
rewards=[]
frames=[]

for ep in range(total_test_episodes):
  state=env.reset()
  step=0
  done=False
  total_rewards=0
  print("Episode",ep)
  for step in range(max_steps):
    print(env.render()[0])
    time.sleep(0.5)
    action=np.argmax(q[state][:])
    new_state,reward,done,info=env.step(action)
    total_rewards=total_rewards+reward

    if done==True:
      rewards.append(total_rewards)
      print("Total Rewards",total_rewards)
      break

    state=new_state

env.close()

print("Done")
print ("Score over time: " +  str(sum(rewards)/total_test_episodes))
q
# Out:
# possible states: 500
# possible action: 6
# Episode 0
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# +---------+
# |R: | : :G|
# |_: | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# +---------+
# |R: | : :G|
# | : | : : |
# |_: : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# +---------+
# |R: | : :G|
# | : | : : |
# | :_: : : |
# ...
